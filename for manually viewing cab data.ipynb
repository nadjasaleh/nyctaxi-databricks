# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2017 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2017 Green Taxi Trip Data")
display(df.limit(5))

# %%
#df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2018 Yellow Taxi Trip Data")
#display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2018 Green Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2019 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2019 Green Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2019 High Volume FHV Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2020 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2020 Green Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2020 High Volume FHV Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2021 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2021 Green Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2021 High Volume FHV Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2022 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2022 Green Taxi Trip Data")
display(df.limit(3))

# %%
#df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2022 High Volume FHV Trip Data")
#display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2023 Yellow Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2023 Green Taxi Trip Data")
display(df.limit(3))

# %%
df = spark.read.json("/Volumes/group3_gp/adlslanding/looped_data/2023 High Volume FHV Trip Data")
display(df.limit(8))
