# %%
# Basic syntax for reading a JSON file
df = spark.read.format("json") \
  .option("inferSchema", "true") \
  .load("/Volumes/group3_gp/adlslanding/looped_data/2020 High Volume FHV Trip Data")

# Show the results
display(df)

# %%
#df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("group3_gp.bronze.2020_green")
